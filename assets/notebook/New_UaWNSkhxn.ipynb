# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df_data_1 = pd.read_csv('/project_data/data_asset/PewDiePie.csv')
df_data_1.head()
# Out:
#    Date  Subscribers
# 0     1        71915
# 1     2        48270
# 2     3        47746
# 3     4        42276
# 4     5        36867
